# %% [markdown]
# # Keşif

# %%
import numpy as np
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import os

# %% [markdown]
# ## Veriyi Al

# %%
from olist.data import Olist
data = Olist().get_data()

# %% [markdown]
# Olist e-ticaret platformundaki her işlem şu özelliklere sahiptir:
# - satın alacak olan bir `customer_id`...
# - çeşitli `product_id`...
# - bir `seller_id`...
# - ve bir `review_id`...
# - tüm bunlar bir `order_id`'ye aittir.

# %% [markdown]
# ## Çeşitli DataFrame'lerinizin kardinalitelerini araştırın

# %% [markdown]
# ❓ **Kaç tane benzersiz `orders`, `reviews`, `sellers`, `products` and `customers` var ?**

# %%
print("Benzersiz Sipariş (Orders):", data['orders']['order_id'].nunique())
print("Benzersiz Yorum (Reviews):", data['order_reviews']['review_id'].nunique())
print("Benzersiz Satıcı (Sellers):", data['sellers']['seller_id'].nunique())
print("Benzersiz Ürün (Products):", data['products']['product_id'].nunique())
print("Benzersiz Müşteri (Customers):", data['customers']['customer_id'].nunique())
# Out:
# Benzersiz Sipariş (Orders): 99441
# Benzersiz Yorum (Reviews): 98410
# Benzersiz Satıcı (Sellers): 3095
# Benzersiz Ürün (Products): 32951
# Benzersiz Müşteri (Customers): 99441

# %% [markdown]
# ❓ **Sipariş başına kaç tane yorum(reviews) var? Tüm siparişler için yorum var mı?**
# <details>
#     <summary markdown=‘span’>İpuçları</summary>
#
# Bu bilgiye bireysel csv dosyanızdan doğrudan erişemezsiniz. Öğrenmek için tabloları birleştirmeniz gerekir. Hangi tür birleştirme yapmanız gerektiğini düşünün.
#
# Hangi tablolara ihtiyacınız olduğundan emin değil misiniz? Öğrenmek için ERD'nize geri dönün.
#
# Yorum sayısını öğrenmek için: `order_id` başına yorum sayısını sayın ve bir histogram çizin. Pandas serisinde `.hist()` kullanabilirsiniz.
# </details>

# %%
total_orders = data['orders']['order_id'].nunique()
reviewed_orders = data['order_reviews']['order_id'].nunique()

print(f"Toplam verilen sipariş sayısı: {total_orders}")
print(f"Yorum yapılan sipariş sayısı: {reviewed_orders}")
print(f"Aradaki fark (Yorumsuz siparişler): {total_orders - reviewed_orders}")
# Out:
# Toplam verilen sipariş sayısı: 99441
# Yorum yapılan sipariş sayısı: 98673
# Aradaki fark (Yorumsuz siparişler): 768

# %% [markdown]
# 🧪 **Test your code below**

# %% [markdown]
# Yorum eksik olan siparişlerin sayısını `int` olarak `n_missing_reviews` adlı bir değişkende saklayın.

# %%
n_missing_reviews = total_orders - reviewed_orders
n_missing_reviews
# Out:
# 768

# %%
from nbresult import ChallengeResult

result = ChallengeResult('exploratory',
    n=n_missing_reviews
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /home/cevdetkopuz/.pyenv/versions/3.12.9/envs/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /home/cevdetkopuz/workintech/sprint-15/01-Statistical-Inference/data-exploratory-analysis/tests
# plugins: typeguard-4.4.2, anyio-4.8.0
# collecting ... collected 1 item
#
# test_exploratory.py::TestExploratory::test_n_missing_reviews PASSED      [100%]
#
# ============================== 1 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/exploratory.pickle
#
# git commit -m 'Completed exploratory step'
#
# git push origin master
